# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
data=pd.read_excel("/content/01 Train Data.xlsx")
data
# Out:
#      First Name           Email ID  Quantity  Price Tier  \
# 0        ANIKET     aniket@xyz.com         1         NaN
# 1     Dhanshree  dhanshree@xyz.com         1         NaN
# 2        Dhiraj     dhiraj@xyz.com         1         NaN
# 3         Pooja      pooja@xyz.com         1         NaN
# 4        Aayush     aayush@xyz.com         1         NaN
# ...         ...                ...       ...         ...
# 4889   Saif ali    saifali@xyz.com         1         NaN
# 4890    Lankesh    lankesh@xyz.com         1         NaN
# 4891     Sanjay     sanjay@xyz.com         1         NaN
# 4892   Sushmita   sushmita@xyz.com         1         NaN
# 4893      Vipul      vipul@xyz.com         1         NaN
#
#                             Ticket Type    Attendee #  Group  Order Type  \
# 0                Art of Resume Building  2.213855e+09    NaN  Free Order
# 1                Art of Resume Building  2.213859e+09    NaN  Free Order
# ...

# %%
data = data.drop_duplicates(subset=['First Name', 'Email ID'])

# %%
data = data.drop_duplicates(subset=[ 'Email ID'])

# %%
data
# Out:
#      First Name           Email ID  Quantity  Price Tier  \
# 0        ANIKET     aniket@xyz.com         1         NaN
# 1     Dhanshree  dhanshree@xyz.com         1         NaN
# 2        Dhiraj     dhiraj@xyz.com         1         NaN
# 3         Pooja      pooja@xyz.com         1         NaN
# 4        Aayush     aayush@xyz.com         1         NaN
# ...         ...                ...       ...         ...
# 4829      Kevin      kevin@xyz.com         1         NaN
# 4831      Hemil      hemil@xyz.com         1         NaN
# 4832     Shitij     shitij@xyz.com         1         NaN
# 4834      dirgh      dirgh@xyz.com         1         NaN
# 4836   UTkarsha   utkarsha@xyz.com         1         NaN
#
#                                    Ticket Type    Attendee #  Group  \
# 0                       Art of Resume Building  2.213855e+09    NaN
# 1                       Art of Resume Building  2.213859e+09    NaN
# 2                       Art of Resume Building  2.213862e+09    NaN
# ...

# %%
data["Placement Status"] = data["Placement Status"].map({"Placed": 1, "Not placed": 0})

# %%
data = data.dropna(subset=["Placement Status"])

# %%
data
# Out:
#      First Name           Email ID  Quantity  Price Tier  \
# 0        ANIKET     aniket@xyz.com         1         NaN
# 1     Dhanshree  dhanshree@xyz.com         1         NaN
# 2        Dhiraj     dhiraj@xyz.com         1         NaN
# 3         Pooja      pooja@xyz.com         1         NaN
# 4        Aayush     aayush@xyz.com         1         NaN
# ...         ...                ...       ...         ...
# 1086   Chaitali   chaitali@xyz.com         1         NaN
# 1090  Nividita    nividita@xyz.com         1         NaN
# 1094     Somesh     somesh@xyz.com         1         NaN
# 1096     Sumedh     sumedh@xyz.com         1         NaN
# 1097    Roheeni    roheeni@xyz.com         1         NaN
#
#                  Ticket Type    Attendee #  Group  Order Type Currency  \
# 0     Art of Resume Building  2.213855e+09    NaN  Free Order      USD
# 1     Art of Resume Building  2.213859e+09    NaN  Free Order      USD
# ...

# %%
# !pip install autoviz
from autoviz.AutoViz_Class import AutoViz_Class
# %matplotlib inline
AV = AutoViz_Class()
AV.AutoViz(filename='',dfte=data,depVar='Placement Status',verbose=1,max_rows_analyzed=data.shape[0]
               ,max_cols_analyzed=data.shape[1])
# Out:
# ...
# Shape of your Data Set loaded: (666, 4)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     3 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# Since Number of Rows in data 666 exceeds maximum, randomly sampling 666 rows for EDA...
#
# ################ Binary_Classification problem #####################
# To fix data quality issues automatically, import FixDQ from autoviz...
#     Alert: Dropping 357 duplicate rows can sometimes cause column data types to change to object. Double-check!
# <style type="text/css">
# ...

# %%
relevant_columns = ["CGPA", "Speaking Skills", "ML Knowledge", "Placement Status"]
data = data[relevant_columns]
data
# Out:
#       CGPA  Speaking Skills  ML Knowledge  Placement Status
# 0      6.7         2               5              1.0
# 1      8.2         3               2              0.0
# 2      6.5         4               3              0.0
# 3      8.7         2               5              0.0
# 4      9.1         3               5              1.0
# ...    ...              ...           ...               ...
# 1086   7.6         4               4              1.0
# 1090   6.7         4               4              1.0
# 1094   9.2         5               5              0.0
# 1096   7.3         2               2              0.0
# 1097   7.3         2               2              0.0
#
# [666 rows x 4 columns]

# %%
data
# Out:
#       CGPA  Speaking Skills  ML Knowledge  Placement Status
# 0      6.7         2               5              1.0
# 1      8.2         3               2              0.0
# 2      6.5         4               3              0.0
# 3      8.7         2               5              0.0
# 4      9.1         3               5              1.0
# ...    ...              ...           ...               ...
# 1086   7.6         4               4              1.0
# 1090   6.7         4               4              1.0
# 1094   9.2         5               5              0.0
# 1096   7.3         2               2              0.0
# 1097   7.3         2               2              0.0
#
# [666 rows x 4 columns]

# %%
data['Placement Status'].value_counts()
# Out:
# 0.0    454
# 1.0    212
# Name: Placement Status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
x = data.drop("Placement Status", axis=1)
y = data["Placement Status"]
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(xtrain)
X_test = scaler.transform(xtest)
X_train.shape,X_test.shape
# Out:
# ((466, 3), (200, 3))

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

def print_score(clf, X_train, y_train, X_test, y_test, train=True):
    if train:
        pred = clf.predict(X_train)
        clf_report = pd.DataFrame(classification_report(y_train, pred, output_dict=True))
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(y_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_train, pred)}\n")
        predicted_series = pd.Series(pred)


        value_counts = predicted_series.value_counts()


        print(value_counts)
    elif train==False:
        pred = clf.predict(X_test)
        clf_report = pd.DataFrame(classification_report(y_test, pred, output_dict=True))
        print("Test Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_test, pred)}\n")
        predicted_series = pd.Series(pred)


        value_counts = predicted_series.value_counts()

# %% [markdown]
# #Random Forrest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(random_state=0)

rfc.fit(X_train, ytrain)
RandomForestClassifier(random_state=0)
print_score(rfc, X_train, ytrain, X_test, ytest, train=True)
print_score(rfc, X_train, ytrain, X_test, ytest, train=False)
# Out:
# Train Result:
# ...
# Accuracy Score: 79.83%
# _______________________________________________
# CLASSIFICATION REPORT:
#                0.0         1.0     accuracy   macro avg  weighted avg
# precision    0.814714    0.737374  0.798283    0.776044     0.791313
# recall       0.920000    0.517730  0.798283    0.718865     0.798283
# f1-score     0.864162    0.608333  0.798283    0.736248     0.786755
# support    325.000000  141.000000  0.798283  466.000000   466.000000
# _______________________________________________
# Confusion Matrix:
#  [[299  26]
#  [ 68  73]]
#
# 0.0    367
# 1.0     99
# dtype: int64
# Test Result:
# ...
# Accuracy Score: 58.50%
# _______________________________________________
# CLASSIFICATION REPORT:
#                0.0        1.0     accuracy   macro avg  weighted avg
# precision    0.661972   0.396552    0.585     0.529262     0.567748
# recall       0.728682   0.323944    0.585     0.526313     0.585000
# ...

# %%
from joblib import dump
dump(rfc,'random_forest_model.joblib')
# Out:
# ['random_forest_model.joblib']

# %% [markdown]
# Choosing Random Forest

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from joblib import dump,load

# %% [markdown]
# ##Predictions on TestData

# %%
model = load('random_forest_model.joblib')
testdata= pd.read_excel('/content/02 Test Data.xlsx')
testdata
# Out:
#       First Name       Email ID       Quantity  Price Tier  \
# 0         Sahil        sahil@xyz.com      1        NaN
# 1        Amrita       amrita@xyz.com      1        NaN
# 2          Mamta       mamta@xyz.com      1        NaN
# 3     Bhagyashri  bhagyashri@xyz.com      1        NaN
# 4      Divyanshu   divyanshu@xyz.com      1        NaN
# ...          ...                 ...       ...         ...
# 3791    Saif ali     saifali@xyz.com      1        NaN
# 3792     Lankesh     lankesh@xyz.com      1        NaN
# 3793      Sanjay      sanjay@xyz.com      1        NaN
# 3794    Sushmita    sushmita@xyz.com      1        NaN
# 3795       Vipul       vipul@xyz.com      1        NaN
#
#                 Ticket Type               Attendee #   Group  Order Type  \
# 0                       Hello ML and DL  2.293940e+09  NaN    Free Order
# 1                       Hello ML and DL  2.293941e+09  NaN    Free Order
# 2                       Hello ML and DL  2.293941e+09  NaN    Free Order
# ...

# %%
testdata = testdata.drop_duplicates(subset=['First Name', 'Email ID'])

# %%
testdata = testdata.drop_duplicates(subset=[ 'Email ID'])

# %%
testdata
# Out:
#        First Name         Email ID        Quantity  Price Tier  \
# 0           Sahil          sahil@xyz.com      1        NaN
# 1          Amrita         amrita@xyz.com      1        NaN
# 2            Mamta         mamta@xyz.com      1        NaN
# 3       Bhagyashri    bhagyashri@xyz.com      1        NaN
# 4        Divyanshu     divyanshu@xyz.com      1        NaN
# ...            ...                   ...       ...         ...
# 3685  Suryaprakash  suryaprakash@xyz.com      1        NaN
# 3687       Rishika       rishika@xyz.com      1        NaN
# 3692      Saif ali       saifali@xyz.com      1        NaN
# 3693       Lankesh       lankesh@xyz.com      1        NaN
# 3695      Sushmita      sushmita@xyz.com      1        NaN
#
#                     Ticket Type                  Attendee #   Group  \
# 0                              Hello ML and DL  2.293940e+09  NaN
# 1                              Hello ML and DL  2.293941e+09  NaN
# ...

# %%
previous_data=testdata["First Name"]

# %%
relevant_columns = ["CGPA", "Speaking Skills", "ML Knowledge"]
testdata = testdata[relevant_columns]
testdata
# Out:
#       CGPA  Speaking Skills  ML Knowledge
# 0      7.8         3               3
# 1      9.1         3               3
# 2      6.9         2               2
# 3      8.4         4               4
# 4      6.7         5               5
# ...    ...              ...           ...
# 3685   8.0         3               3
# 3687   8.5         5               5
# 3692   8.8         3               3
# 3693   9.3         4               4
# 3695   6.5         4               4
#
# [2321 rows x 3 columns]

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(testdata)
scaled_data.shape
# Out:
# (2321, 3)

# %%
model_pred = model.predict(scaled_data)
np.count_nonzero(model_pred==0)
# Out:
# 1801

# %%
testdata['target'] = model_pred

# %%
testdata
# Out:
#       CGPA  Speaking Skills  ML Knowledge  target
# 0      7.8         3               3         0.0
# 1      9.1         3               3         0.0
# 2      6.9         2               2         0.0
# 3      8.4         4               4         0.0
# 4      6.7         5               5         0.0
# ...    ...              ...           ...     ...
# 3685   8.0         3               3         1.0
# 3687   8.5         5               5         0.0
# 3692   8.8         3               3         0.0
# 3693   9.3         4               4         1.0
# 3695   6.5         4               4         1.0
#
# [2321 rows x 4 columns]

# %%
testdata['target'].value_counts()
# Out:
# 0.0    1801
# 1.0     520
# Name: target, dtype: int64

# %%
testdata
# Out:
#       CGPA  Speaking Skills  ML Knowledge  target
# 0      7.8         3               3         0.0
# 1      9.1         3               3         0.0
# 2      6.9         2               2         0.0
# 3      8.4         4               4         0.0
# 4      6.7         5               5         0.0
# ...    ...              ...           ...     ...
# 3685   8.0         3               3         1.0
# 3687   8.5         5               5         0.0
# 3692   8.8         3               3         0.0
# 3693   9.3         4               4         1.0
# 3695   6.5         4               4         1.0
#
# [2321 rows x 4 columns]

# %%
predictions = pd.DataFrame(testdata['target'])
final = pd.concat([previous_data,predictions], axis=1)

# %%
final
# Out:
#        First Name   target
# 0           Sahil     0.0
# 1          Amrita     0.0
# 2            Mamta    0.0
# 3       Bhagyashri    0.0
# 4        Divyanshu    0.0
# ...            ...     ...
# 3685  Suryaprakash    1.0
# 3687       Rishika    0.0
# 3692      Saif ali    0.0
# 3693       Lankesh    1.0
# 3695      Sushmita    1.0
#
# [2321 rows x 2 columns]

# %%
final['target'] = final['target'].replace(1, 'placed')

final['target'] = final['target'].replace(0, 'not placed')

# %%
final["Placment Status"]=final["target"]

# %%
final=final.drop(columns=["target"])

# %%
excel_file_path = 'predictions.xlsx'

# Export DataFrame to Excel
final.to_excel(excel_file_path, index=False)
